# %%
import os
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from datasets import SplatoonDataset, sdata_to
from dateutil.parser import parse as date_parse
from model import SimpleTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
train_path = Path('../../dataset/train_data.csv')
test_path = Path('../../dataset/test_data.csv')

# %%
dataset = SplatoonDataset(str(train_path.absolute()))
dataloader = DataLoader(dataset, batch_size=4)
# Out:
# building vocabulary: 100%|██████████| 66125/66125 [00:02<00:00, 30907.64it/s]

# %%
x, y = next(iter(dataloader))
y
# Out:
# tensor([1, 0, 0, 0])

# %%
x.lobby
# Out:
# ('standard', 'standard', 'standard', 'standard')

# %%
n_lobby_modes = len(dataset.lobby_mode_vocab)
n_modes = len(dataset.mode_vocab)
n_weapons = len(dataset.weapon_vocab)
n_ranks = len(dataset.rank_vocab)
n_stages = len(dataset.stage_vocab)

# %%
st = SimpleTransformer(n_lobby_modes, n_modes, n_stages, n_weapons, n_ranks, 12)
out = st(x)
st = st.train()

# %%
optimizer = optim.Adam(st.parameters())
criterion = nn.CrossEntropyLoss()

# %%
loss = criterion(out, y)
loss.detach().numpy()
# Out:
# array(1.6151538, dtype=float32)

# %%
train_ds, test_ds = train_test_split(dataset, test_size=0.1)
train_ds
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-c18e488b1a06> in <module>
#       1 train_ds, test_ds = train_test_split(dataset, test_size=0.1)
# ----> 2 SplatoonDataset(train_ds)
#
# /home/JupyterLab/codes/prob_space/splatoon_competition/models/pytorch/datasets.py in __init__(self, filename)
#      42     def __init__(self, filename):
#      43         self.filename = filename
# ---> 44         self.__build_vocab()
#      45
#      46     def __len__(self):
#
# /home/JupyterLab/codes/prob_space/splatoon_competition/models/pytorch/datasets.py in __build_vocab(self)
#      89         self.total = 0
#      90
# ---> 91         with open(self.filename) as f_it:
#      92
#      93             next(f_it)  # skip header
#
# TypeError: expected str, bytes or os.PathLike object, not Subset

# %%
print(accuracy_score(out.argmax(axis=-1).detach().cpu().numpy(), y.detach().cpu().numpy()))
print(precision_score(out.argmax(axis=-1).detach().cpu().numpy(), y.detach().cpu().numpy()))
print(recall_score(out.argmax(axis=-1).detach().cpu().numpy(), y.detach().cpu().numpy()))
print(f1_score(out.argmax(axis=-1).detach().cpu().numpy(), y.detach().cpu().numpy()))
# Out:
# 0.25
# 0.0
# 0.0
# 0.0

# %%
train_ds.__class__ = SplatoonDataset
next(iter(DataLoader(train_ds, batch_size=4)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-7b0f31613af1> in <module>
#       1 train_ds.__class__ = SplatoonDataset
# ----> 2 next(iter(DataLoader(train_ds, batch_size=4)))
#
# /usr/local/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __iter__(self)
#     287     def __iter__(self):
#     288         if self.num_workers == 0:
# --> 289             return _SingleProcessDataLoaderIter(self)
#     290         else:
#     291             return _MultiProcessingDataLoaderIter(self)
#
# /usr/local/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __init__(self, loader)
#     396         assert self._num_workers == 0
#     397
# --> 398         self._dataset_fetcher = _DatasetKind.create_fetcher(
#     399             self._dataset_kind, self._dataset, self._auto_collation, self._collate_fn, self._drop_last)
#     400
#
# /usr/local/lib/python3.8/site-packages/torch/utils/data/dataloader.py in create_fetcher(kind, dataset, auto_collation, collate_fn, drop_last)
#      39             return _utils.fetch._MapDatasetFetcher(dataset, auto_collation, collate_fn, drop_last)
#      40         else:
# ---> 41             return _utils.fetch._IterableDatasetFetcher(dataset, auto_collation, collate_fn, drop_last)
#      42
#      43
#
# /usr/local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in __init__(self, dataset, auto_collation, collate_fn, drop_last)
#      19     def __init__(self, dataset, auto_collation, collate_fn, drop_last):
#      20         super(_IterableDatasetFetcher, self).__init__(dataset, auto_collation, collate_fn, drop_last)
# ---> 21         self.dataset_iter = iter(dataset)
#      22
#      23     def fetch(self, possibly_batched_index):
#
# /home/JupyterLab/codes/prob_space/splatoon_competition/models/pytorch/datasets.py in __iter__(self)
#     145
#     146     def __iter__(self):
# --> 147         f_itr = open(self.filename)
#     148
#     149         # skip headers
#
# AttributeError: 'SplatoonDataset' object has no attribute 'filename'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-a9c788a0170b> in <module>
# ----> 1 x.to('cpu')
#
# AttributeError: 'SData' object has no attribute 'to'
